# %% [markdown]
# # GWAS Workshop
#
# Run a complete GWAS analysis: variant lookup across 9 databases, polygenic risk scores, and SuSiE fine-mapping.
#
# | | |
# |---|---|
# | **Level** | Intermediate |
# | **Time** | ~30 min |
# | **Requirements** | Google account |
# | **Full tutorial** | [docs.clawbio.ai/tutorials/gwas-workshop](https://docs.clawbio.ai/tutorials/gwas-workshop/) |
# | **Slides** | [clawbio.ai/workshop-gwas-slides.html](https://clawbio.ai/workshop-gwas-slides.html) |

# %% [markdown]
# ## Step 0: Setup

# %%
# !git clone --depth 1 https://github.com/ClawBio/ClawBio.git
# %cd ClawBio
# !pip install -q -r requirements.txt
print("\n✓ ClawBio installed successfully")

# %% [markdown]
# ## Step 1: GWAS Lookup
#
# Query rs7903146 (the strongest common Type 2 diabetes signal, in TCF7L2) across 9 databases: GWAS Catalog, Open Targets, UKB, FinnGen, Biobank Japan, GTEx, eQTL Catalogue, and more.

# %%
# !python3 skills/gwas-lookup/gwas_lookup.py --demo --output /tmp/gwas-lookup-demo

# %%
from IPython.display import Markdown
Markdown(open('/tmp/gwas-lookup-demo/report.md').read())

# %% [markdown]
# ### Try another variant
# Look up rs429358 (APOE, Alzheimer's risk). You found this in the Variant Interpretation Workshop. Now see the population-level GWAS context.

# %%
# !python3 skills/gwas-lookup/gwas_lookup.py --rsid rs429358 --output /tmp/gwas-apoe

# %%
Markdown(open('/tmp/gwas-apoe/report.md').read())

# %% [markdown]
# ## Step 2: Polygenic Risk Scores
#
# Compute PRS for 6 traits using the Corpasome (Manuel Corpas's 23andMe data). The tool matches genotyped variants to published PGS Catalog scoring files and estimates percentile rank.

# %%
# !python3 skills/gwas-prs/gwas_prs.py --demo --output /tmp/prs-demo

# %%
Markdown(open('/tmp/prs-demo/report.md').read())

# %% [markdown]
# ## Step 3: SuSiE Fine-Mapping
#
# GWAS finds associated regions. Fine-mapping finds the causal variants within them. SuSiE produces credible sets: the minimal set of SNPs capturing 95% of causal probability.

# %%
# !python3 skills/fine-mapping/fine_mapping.py --demo --output /tmp/finemapping-demo

# %%
Markdown(open('/tmp/finemapping-demo/report.md').read())

# %% [markdown]
# ### View the locus plot

# %%
from IPython.display import Image
import glob
plots = glob.glob('/tmp/finemapping-demo/figures/*.png')
if plots:
    display(Image(plots[0]))
else:
    print('No figure generated (this is OK for the demo)')

# %% [markdown]
# ## Step 4: Exercises
#
# 1. **Cross-ancestry comparison**: Look up rs7903146 and compare allele frequencies between UKB, FinnGen, and Biobank Japan in the report. How do they differ?
#
# 2. **Your own variant**: Pick any rsID from a GWAS paper and look it up:
#    ```python
#    !python3 skills/gwas-lookup/gwas_lookup.py --rsid YOUR_RSID --output /tmp/my-variant
#    ```
#
# 3. **PRS with your own data**: If you have a 23andMe file, upload it and run:
#    ```python
#    !python3 skills/gwas-prs/gwas_prs.py --input YOUR_FILE.txt --trait "type 2 diabetes" --output /tmp/my-prs
#    ```

# %% [markdown]
# ## Take-home Messages
#
# 1. **GWAS summary statistics are free and public.** No HPC, no data agreements needed.
# 2. **Three skills cover the full workflow**: lookup, PRS, and fine-mapping.
# 3. **Cross-ancestry analysis is not optional.** Most GWAS are European-biased.
# 4. **Fine-mapping narrows GWAS hits to causal variants.** SuSiE credible sets are state of the art.
# 5. **Infrastructure is no longer a barrier.** Google Colab + ClawBio = publication-quality GWAS for free.
#
# ---
#
# **Next:** [30x WGS Workshop](https://docs.clawbio.ai/tutorials/30x-wgs-workshop/)
#
# *ClawBio is a research and educational tool. It is not a medical device.*
